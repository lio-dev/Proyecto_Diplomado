# %%
import scipy.stats as stats

import pandas as pd
import scipy.stats as stats
import numpy as np

# %%
data = pd.read_csv('preparacion de datos\indicadores_municipios_cpv-2012_cod.csv')
data_frame = pd.read_csv('preparacion de datos\establecimientos de salud\minsalud_numero_establecimientos_por_nivel_de_atencion_al_2009.csv')
# Mostrar el DataFrame
data
# Out:
#      cod.mun departamento_y_municipio  t_2001    h_01    m_01  t_2012    h_12  \
# 0      10101                    Sucre  214913  102930  111983  261201  124667
# 1      10102                   Yotala    9497    4663    4834    9461    4704
# 2      10103                   Poroma   16966    8479    8487   17377    8714
# 3      10201                  Azurduy   11349    5573    5776   10652    5414
# 4      10202                  Tarvita   15791    7869    7922   14261    7237
# ..       ...                      ...     ...     ...     ...     ...     ...
# 334    90401               Santa Rosa    2097    1243     854    2395    1442
# 335    90402                   Ingavi     899     547     352    1654     953
# 336    90501          Nueva Esperanza     740     465     275    2068    1279
# 337    90502  Villa Nueva - Loma Alta     993     558     435    2801    1512
# 338    90503           Santos Mercado     509     351     158    2165    1300
#
# ...

# %%
print(data.columns)
# Out:
# Index(['cod.mun', 'departamento_y_municipio', 't_2001', 'h_01', 'm_01',
#        't_2012', 'h_12', 'm_12', 'tmn_2001_2012(%)', 'tac_ 2001_2012(%)',
#        'ind_mas', 'urbana', 'rural', 'pob_insrc_%', 'pob_ci_%', 't_taf>15',
#        'h_>15', 'm_>15', 't_ae(6_19)', 'h_ae(6_19)', 'm_ae(6_19)',
#        'nin_(ni>19)', 'prim_(ni>19)', 'se_(ni>19)', 'sup_(ni>19)',
#        'ins_(ni>19)', 'otro_(ni>19)', 't_aest', 'h_aest', 'm_aest',
#        'est_sal_ultpar', 'dom_ultpar', 'otro_ultpar', 'sinesp_ultpar'],
#       dtype='object')

# %%
selected_columns = ['cod.mun', 'departamento_y_municipio', 't_2001', 'h_01', 'm_01',
                    't_2012', 'h_12', 'm_12', 'tmn_2001_2012(%)', 'tac_ 2001_2012(%)','est_sal_ultpar', 'dom_ultpar']

data = data.loc[:, selected_columns]

# Mostrar el DataFrame resultante
data
# Out:
#      cod.mun departamento_y_municipio  t_2001    h_01    m_01  t_2012    h_12  \
# 0      10101                    Sucre  214913  102930  111983  261201  124667
# 1      10102                   Yotala    9497    4663    4834    9461    4704
# 2      10103                   Poroma   16966    8479    8487   17377    8714
# 3      10201                  Azurduy   11349    5573    5776   10652    5414
# 4      10202                  Tarvita   15791    7869    7922   14261    7237
# ..       ...                      ...     ...     ...     ...     ...     ...
# 334    90401               Santa Rosa    2097    1243     854    2395    1442
# 335    90402                   Ingavi     899     547     352    1654     953
# 336    90501          Nueva Esperanza     740     465     275    2068    1279
# 337    90502  Villa Nueva - Loma Alta     993     558     435    2801    1512
# 338    90503           Santos Mercado     509     351     158    2165    1300
#
# ...

# %%
ruta_guardar_csv = 'D:\Proyecto diplomado - Leonel Lizarraga\datasets actualizados\dataset_csv\censo_poblacional_2012.csv'  # Reemplaza con la ruta completa donde deseas guardar el archivo CSV
data.to_csv(ruta_guardar_csv, index=False)
