# %%
import scipy.stats as stats
import pandas as pd
import scipy.stats as stats
import numpy as np

# %%
import pandas as pd
from IPython.display import display, HTML

# Leer el archivo CSV
data = pd.read_csv('preparacion de datos\\registro de nacimientos\\minsalud_registro_nacidos.csv')


# Lista de columnas a eliminar
columnas_a_eliminar = ['nacidos_vivos', 'nacidos_vivos_atendidos_por_personal_de_salud']

# Eliminar las columnas
data = data.drop(columnas_a_eliminar, axis=1)

# Manejar valores no finitos antes de la conversión
columnas_enteras = ['nacidos_muertos', 'nacidos_muertos_atendidos_por_partera']
data[columnas_enteras] = data[columnas_enteras].fillna(0).astype(int)

# Supongamos que 'columna1' y 'columna2' son tus columnas numéricas
columnas_numericas = ['nacidos_muertos', 'nacidos_muertos_atendidos_por_partera', 'total_general']

# Crear un estilo para centrar todas las celdas
styles = [
    {'selector': 'td', 'props': [('text-align', 'center')]},
    {'selector': 'th', 'props': [('text-align', 'center')]}
]

# Aplicar estilo general para centrar toda la tabla
styled_data = data.style.set_table_styles(styles)

# Mostrar la tabla estilizada
display(styled_data)
# Out:
# <style type="text/css">
# #T_52aa6 td {
#   text-align: center;
# }
# #T_52aa6 th {
#   text-align: center;
# }
# </style>
# <table id="T_52aa6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_52aa6_level0_col0" class="col_heading level0 col0" >id</th>
#       <th id="T_52aa6_level0_col1" class="col_heading level0 col1" >cod_dep</th>
#       <th id="T_52aa6_level0_col2" class="col_heading level0 col2" >departamento</th>
#       <th id="T_52aa6_level0_col3" class="col_heading level0 col3" >cod_mun</th>
#       <th id="T_52aa6_level0_col4" class="col_heading level0 col4" >municipio</th>
#       <th id="T_52aa6_level0_col5" class="col_heading level0 col5" >nacidos_muertos</th>
#       <th id="T_52aa6_level0_col6" class="col_heading level0 col6" >nacidos_muertos_atendidos_por_personal_de_salud</th>
#       <th id="T_52aa6_level0_col7" class="col_heading level0 col7" >nacidos_muertos_atendidos_por_partera</th>
# ...

# %%
ruta_guardar_csv = 'D:\\Proyecto diplomado - Leonel Lizarraga\\datasets actualizados\\registro de nacimientos\\registro_de_nacimientos.csv'  
data.to_csv(ruta_guardar_csv, index=False)
